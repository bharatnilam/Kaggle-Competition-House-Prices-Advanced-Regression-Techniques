# %% [markdown]
# # Kaggle Competition: House Prices - Advanced Regression Techniques
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques

# %% [markdown]
# ## Contents
# - Import Libraries
# - Data Cleaning
# - Feature Engineering

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
full = pd.concat([train, test], ignore_index=True)

# %%
full.drop(['Id'], axis=1, inplace=True)

# %%
full.shape
# Out:
# (2919, 80)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Missing Data

# %%
null_val = full.isnull().sum()
null_val[null_val>0].sort_values(ascending=False)
# Out:
# PoolQC          2909
# MiscFeature     2814
# Alley           2721
# Fence           2348
# SalePrice       1459
# FireplaceQu     1420
# LotFrontage      486
# GarageYrBlt      159
# GarageFinish     159
# GarageQual       159
# GarageCond       159
# GarageType       157
# BsmtCond          82
# BsmtExposure      82
# BsmtQual          81
# BsmtFinType2      80
# BsmtFinType1      79
# MasVnrType        24
# MasVnrArea        23
# MSZoning           4
# BsmtFullBath       2
# BsmtHalfBath       2
# Functional         2
# Utilities          2
# BsmtFinSF2         1
# BsmtUnfSF          1
# BsmtFinSF1         1
# TotalBsmtSF        1
# SaleType           1
# KitchenQual        1
# Exterior2nd        1
# Exterior1st        1
# GarageCars         1
# GarageArea         1
# Electrical         1
# dtype: int64

# %%
cols1 = ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 'GarageFinish', 'GarageQual', 'GarageCond', 'GarageType', 'BsmtCond', 'BsmtExposure', 'BsmtQual', 'BsmtFinType2', 'BsmtFinType1', 'MasVnrType']
for col in cols1:
    full[col].fillna("None", inplace=True)

# %%
full['LotFrontage'].fillna(full['LotFrontage'].mean(), inplace=True)

# %%
full['GarageYrBlt'].fillna(0, inplace=True)

# %%
cols2 = ['MasVnrArea', 'GarageArea', 'TotalBsmtSF', 'BsmtUnfSF', 'BsmtFinSF2', 'BsmtFinSF1']
for col in cols2:
    full[col].fillna(full[col].median(), inplace=True)

# %%
cols3 = ['MSZoning', 'Functional', 'BsmtHalfBath', 'BsmtFullBath', 'Utilities', 'SaleType', 'GarageCars', 'KitchenQual', 'Electrical', 'Exterior2nd', 'Exterior1st']
for col in cols3:
    full[col].fillna(full[col].mode()[0], inplace=True)

# %%
full.isnull().sum()[full.isnull().sum()>0]
# Out:
# SalePrice    1459
# dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.heatmap(full.isnull(), yticklabels=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Feature Engineering

# %%
full['LotFrontage'].skew()
# Out:
# 1.6464199597415903
